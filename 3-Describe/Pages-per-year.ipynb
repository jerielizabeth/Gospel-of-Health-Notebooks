# %%
import os
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import re

# %%
final_dirs = "/Users/jeriwieringa/Dissertation/drafts/data/2017-03-24-final-correction-files.txt"

# %%
with open(final_dirs) as f:
    content = [x.strip() for x in f.readlines()]

# %%
content
# Out:
# ['ADV/correction15',
#  'AmSn/correction9',
#  'ARAI/correction7',
#  'CE/correction9',
#  'CUV/correction9',
#  'EDU/correction9',
#  'GCB/correction9',
#  'GH/correction8',
#  'GoH/correction9',
#  'GS/correction7',
#  'HM/correction9',
#  'HR/correction9',
#  'IR/correction9',
#  'LB/correction9',
#  'LH/correction9',
#  'LibM/correction10',
#  'LUH/correction7',
#  'NMN/correction8',
#  'PHJ/correction9',
#  'PTAR/correction7',
#  'PUR/correction8',
#  'RH1850-1889/correction8',
#  'RH1890-1920/correction9',
#  'Sligo/correction8',
#  'SOL/correction6',
#  'ST/correction9',
#  'SUW/correction8',
#  'TCOG/correction6',
#  'TMM/correction6',
#  'WMH/correction8',
#  'YI/correction10']

# %%
text_dir = "/Users/jeriwieringa/Dissertation/text/text/2017-01-31-corpus-with-utf8-split-into-titles-cleaning/"

# %%
filenames = []
for each in content:
    dir_name = os.path.join(text_dir, each)
    pref = each.split('/')[0]
    pages = [name for name in os.listdir(dir_name)]
    filenames.append(pages)

# %%
def extract_title_info(dictionary, page_list):
    for page in page_list:
        split_page = page.split('-')
        
        title = re.match("[A-Za-z]+", split_page[0])
        dates = re.search(r'[0-9]+', split_page[0])
        
        year = dates.group()[:4]

        dictionary[page] = {'title': title.group(), 'year': year}

# %%
pages = {}

# %%
for each in filenames:
#     print(each)
    extract_title_info(pages, each)

# %%
df = pd.DataFrame.from_dict(pages, orient='index')

# %%
df
# Out:
#                                year title
# ADV18981201-V02-01-page1.txt   1898   ADV
# ADV18981201-V02-01-page10.txt  1898   ADV
# ADV18981201-V02-01-page11.txt  1898   ADV
# ADV18981201-V02-01-page12.txt  1898   ADV
# ADV18981201-V02-01-page13.txt  1898   ADV
# ADV18981201-V02-01-page14.txt  1898   ADV
# ADV18981201-V02-01-page15.txt  1898   ADV
# ADV18981201-V02-01-page16.txt  1898   ADV
# ADV18981201-V02-01-page17.txt  1898   ADV
# ADV18981201-V02-01-page18.txt  1898   ADV
# ADV18981201-V02-01-page19.txt  1898   ADV
# ADV18981201-V02-01-page2.txt   1898   ADV
# ADV18981201-V02-01-page20.txt  1898   ADV
# ADV18981201-V02-01-page21.txt  1898   ADV
# ADV18981201-V02-01-page22.txt  1898   ADV
# ADV18981201-V02-01-page23.txt  1898   ADV
# ADV18981201-V02-01-page24.txt  1898   ADV
# ADV18981201-V02-01-page25.txt  1898   ADV
# ADV18981201-V02-01-page26.txt  1898   ADV
# ADV18981201-V02-01-page3.txt   1898   ADV
# ADV18981201-V02-01-page4.txt   1898   ADV
# ADV18981201-V02-01-page5.txt   1898   ADV
# 3     ADV  1901   389
# 4     ADV  1902   440
# 5     ADV  1903   428
# 6     ADV  1904   202
# 7     ADV  1905    20
# 8    ARAI  1909    64
# 9    ARAI  1919    32
# 10   AmSn  1886    96
# 11   AmSn  1887    96
# 12   AmSn  1888   105
# 13   AmSn  1889   386
# 14   AmSn  1890   403
# 15   AmSn  1891   398
# 16   AmSn  1892   401
# 17   AmSn  1893   402
# 18   AmSn  1894   402
# 19   AmSn  1895   400
# 20   AmSn  1896   408
# 21   AmSn  1897   800
# 22   AmSn  1898   804
# 23   AmSn  1899   801
# 24   AmSn  1900   800
# 25     CE  1909   104
# 26     CE  1910   312
# 27     CE  1911   312
# 28     CE  1912   306
# 29     CE  1913   420
# ..    ...   ...   ...
# 465    YI  1885   192
# 466    YI  1886   220
# 467    YI  1887   244
# 468    YI  1888   104
# 469    YI  1889   208
# 470    YI  1890   208
# 471    YI  1895   416
# 472    YI  1898    28
# 473    YI  1899   408
# 474    YI  1900   408
# 475    YI  1901   408
# 476    YI  1902   408
# 477    YI  1903   408
# 478    YI  1904   288
# 479    YI  1905   408
# 480    YI  1906   408
# 481    YI  1907   432
# 482    YI  1908   832
# 483    YI  1909   844
# 484    YI  1910   850
# 485    YI  1911   852
# 486    YI  1912   868
# 487    YI  1913   848
# 488    YI  1914   852
# 489    YI  1915   852
# 490    YI  1916   852
# 491    YI  1917   840
# 492    YI  1918   850
# 493    YI  1919   856
# 494    YI  1920    45
#
# [495 rows x 3 columns]

# %%
df2.loc[df2['year'] == '1919']
# Out:
#      title  year  docs
# 9     ARAI  1919    32
# 35      CE  1919   288
# 55     CUV  1919   413
# 117     GH  1919    74
# 205     LB  1919   432
# 222     LH  1919   384
# 235    LUH  1919   624
# 250   LibM  1919   120
# 290    PUR  1919   408
# 361     RH  1919  1664
# 411     ST  1919   768
# 425    SUW  1919   384
# 430  Sligo  1919   340
# 437   TCOG  1919   192
# 493     YI  1919   856

# %%
from bokeh.charts import Bar, show
from bokeh.charts import defaults
from bokeh.palettes import viridis
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="178d8d6f-15fb-4f88-a24e-ec195400976d">Loading BokehJS ...</span>
#     </div>

# %%
defaults.width = 950
defaults.height = 1050

# %%
p = Bar(df2, 
        'year', 
        values='docs',
        agg='sum', 
        stack='title',
        palette= viridis(30), 
        title="Pages per Title per Year")

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1f681cae-5820-4c64-99ea-2330bfc412d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1f681cae-5820-4c64-99ea-2330bfc412d6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1f681cae-5820-4c64-99ea-2330bfc412d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1f681cae-5820-4c64-99ea-2330bfc412d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7c72140a-ace1-48d4-8c48-77a2d078cc7d":{"roots":{"references":[{"attributes":{"data_source":{"id":"494cf8f4-d323-4837-83cf-28897ac3491a","type":"ColumnDataSource"},"glyph":{"id":"79a72822-cfba-43c6-adae-af3f76404a81","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a7140d96-6a5e-41cb-8539-642797f04233","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67972371-50b9-4eb4-81ec-d25b44f4d390","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","height","y","line_alpha","label","color","x","line_color","fill_alpha"],"data":{"chart_index":[{"title":"GCB","year":"1888"}],"color":["#404487"],"fill_alpha":[0.8],"height":[83.0],"label":[{"title":"GCB","year":"1888"}],"line_alpha":[1.0],"line_color":["white"],"title":["GCB"],"width":[0.8],"x":["1888"],"y":[146.5],"year":["1888"]}},"id":"f2785603-868c-4f66-a774-d8ba3de06f34","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","height","y","line_alpha","label","color","x","line_color","fill_alpha"],"data":{"chart_index":[{"title":"AmSn","year":"1892"}],"color":["#48196B"],"fill_alpha":[0.8],"height":[401.0],"label":[{"title":"AmSn","year":"1892"}],"line_alpha":[1.0],"line_color":["white"],"title":["AmSn"],"width":[0.8],"x":["1892"],"y":[200.5],"year":["1892"]}},"id":"4847c5f3-d7d4-4269-9e69-8c8636713a4e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"58550d74-5e2f-45e5-8e96-2704c0ced1b4","type":"ColumnDataSource"},"glyph":{"id":"b499a3d8-a0bf-456c-8539-520614623045","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ec74c4c-9d4e-4f35-84e6-2ce78e431557","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","height","y","line_alpha","label","color","x","line_color","fill_alpha"],"data":{"chart_index":[{"title":"RH","year":"1860"}],"color":["#4DC26B"],"fill_alpha":[0.8],"height":[416.0],"label":[{"title":"RH","year":"1860"}],"line_alpha":[1.0],"line_color":["white"],"title":["RH"],"width":[0.8],"x":["1860"],"y":[208.0],"year":["1860"]}},"id":"9ca6b9da-a227-4112-bfa1-e5d4e598a0ee","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["width","height","y","line_alpha","label","color","x","line_color","fill_alpha"],"data":{"chart_index":[{"title":"YI","year":"1862"}],"color":["#FDE724"],"fill_alpha":[0.8],"height":[96.0],"label":[{"title":"YI","year":"1862"}],"line_alpha":[1.0],"line_color":["white"],"title":["YI"],"width":[0.8],"x":["1862"],"y":[466.0],"year":["1862"]}},"id":"e8bb7275-75e9-4884-99d1-909872afc19b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c98d3248-962a-468e-a590-6fb2e47977b5","type":"ColumnDataSource"},"glyph":{"id":"4f747fdc-8a7e-42e3-8213-0adfb096699c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"89881ee9-8808-4b13-ac81-efdd8504870c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3a7219ba-2ac0-4270-844b-6d7cb13fdf16","type":"ColumnDataSource"},"glyph":{"id":"5a422835-6752-4e73-8cdd-7f475132ddb6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ec69c144-3fd7-48b7-8586-e33870042210","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","height","y","line_alpha","label","color","x","line_color","fill_alpha"],"data":{"chart_index":[{"title":"ST","year":"1910"}],"color":["#74D054"],"fill_alpha":[0.8],"height":[672.0],"label":[{"title":"ST","year":"1910"}],"line_alpha":[1.0],"line_color":["white"],"title":["ST"],"width":[0.8],"x":["1910"],"y":[4942.0],"year":["1910"]}},"id":"3200f480-7b61-437a-a8a7-9d57c1209e07","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field": ...
