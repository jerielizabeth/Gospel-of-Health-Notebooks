# %% [markdown]
# Now that we have a collection of texts [selected and downloaded](http://jeriwieringa.com/2017/04/25/gathering-sources/), and have [extracted the text](http://jeriwieringa.com/2017/04/27/Extract-Text-from-PDFs/), we need to spend some time identifying what the corpus contains, both in terms of coverage and quality. As I describe in the [project overview](http://jeriwieringa.com/2017/04/21/updated-dissertation-description), I will be using these texts to make arguments about the development of the community's discourses around health and salvation. While the corpus makes that analysis possible, it also sets the limits of what we can claim from text analysis alone. Without an understanding of what those limits are, we run the risk of claiming more than the sources can sustain, and in doing so, minimizing the very complexities that historical research seeks to reveal.

# %%
"""My usual practice for gathering the filenames is to read 
them in from a directory. So that this code can be run locally 
without the full corpus downloaded, I exported the list 
of filenames to an index file for use in this notebook.
"""
with open("data/2017-05-05-corpus-index.txt", "r") as f:
    corpus = f.read().splitlines()

# %%
len(corpus)
# Out:
# 197943

# %% [markdown]
# To create an overview of the corpus, I will use the document filenames along with some descriptive metadata that I created.
#
# Filenames are an often underestimated feature of digital files, but one that can be used to great effect. For my corpus, the team that digitized the periodicals did an excellent job of providing the files with descriptive names. Overall, the files conform to the following pattern:
#
# `PrefixYYYYMMDD-V00-00.pdf`
#
# I discovered a few files that deviated from the pattern, but renamed those so that the pattern held throughout the corpus. When splitting the PDF documents into pages, I preserved the structure, adding `-page0.txt` to the end.
#
# The advantage of this format is that the filenames contain the metadata I need to place each file within its context. By isolating the different sections of the filename, I can quickly place any file with reference to the periodical title and the publication date.

# %%
import pandas as pd
import re

# %%
def extract_pub_info(doc_list):
    """Use regex to extract metadata from filename.
    
    Note:
        Assumes that the filename is formatted as::
            
            `PrefixYYYYMMDD-V00-00.pdf`
    
    Args:
        doc_list (list): List of the filenames in the corpus.
    Returns:
        dict: Dictionary with the year and title abbreviation for each filename.
    """
    
    corpus_info = {}
    
    for doc_id in doc_list:
        
        # Split the ID into three parts on the '-'
        split_doc_id = doc_id.split('-')
        
        # Get the prefix by matching the first set of letters 
        # in the first part of the filename.
        title = re.match("[A-Za-z]+", split_doc_id[0])
        # Get the dates by grabbing all of the number elements 
        # in the first part of the filename.
        dates = re.search(r'[0-9]+', split_doc_id[0])
        # The first four numbers is the publication year.
        year = dates.group()[:4]
        
        # Update the dictionary with the title and year 
        # for the filename.
        corpus_info[doc_id] = {'title': title.group(), 'year': year}
    
    return corpus_info

# %%
corpus_info = extract_pub_info(corpus)

# %% [markdown]
# One of the most useful libraries in Python for working with data is [Pandas](http://pandas.pydata.org/). With Pandas, Python users gain much of the functionality that our colleagues who work with R have long celebrated as the benefits of that domain-specific language.
#
# By transforming our `corpus_info` dictionary into a dataframe, we can quickly filter and tabulate a number of different statistics on our corpus.

# %%
df = pd.DataFrame.from_dict(corpus_info, orient='index')

# %%
df.index.name = 'docs'
df = df.reset_index()

# %% [markdown]
# You can preview the initial dataframe by uncommenting the cell below.

# %%
# df

# %%
df = df.groupby(["title", "year"], as_index=False).docs.count()

# %%
df
# Out:
#     title  year  docs
# 0     ADV  1898    26
# 1     ADV  1899   674
# 2     ADV  1900   463
# 3     ADV  1901   389
# 4     ADV  1902   440
# 5     ADV  1903   428
# 6     ADV  1904   202
# 7     ADV  1905    20
# 8    ARAI  1909    64
# 9    ARAI  1919    32
# 10   AmSn  1886    96
# 11   AmSn  1887    96
# 12   AmSn  1888   105
# 13   AmSn  1889   386
# 14   AmSn  1890   403
# 15   AmSn  1891   398
# 16   AmSn  1892   401
# 17   AmSn  1893   402
# 18   AmSn  1894   402
# 19   AmSn  1895   400
# 20   AmSn  1896   408
# 21   AmSn  1897   800
# 22   AmSn  1898   804
# 23   AmSn  1899   801
# 24   AmSn  1900   800
# 25     CE  1909   104
# 26     CE  1910   312
# 27     CE  1911   312
# 28     CE  1912   306
# 29     CE  1913   420
# ..    ...   ...   ...
# 465    YI  1885   192
# 466    YI  1886   220
# 467    YI  1887   244
# 468    YI  1888   104
# 469    YI  1889   208
# 470    YI  1890   208
# 471    YI  1895   416
# 472    YI  1898    28
# 473    YI  1899   408
# 474    YI  1900   408
# 475    YI  1901   408
# 476    YI  1902   408
# 477    YI  1903   408
# 478    YI  1904   288
# 479    YI  1905   408
# 480    YI  1906   408
# 481    YI  1907   432
# 482    YI  1908   832
# 483    YI  1909   844
# 484    YI  1910   850
# 485    YI  1911   852
# 486    YI  1912   868
# 487    YI  1913   848
# 488    YI  1914   852
# 489    YI  1915   852
# 490    YI  1916   852
# 491    YI  1917   840
# 492    YI  1918   850
# 493    YI  1919   856
# 494    YI  1920    45
#
# [495 rows x 3 columns]

# %% [markdown]
# Nearly 500 rows of data is too large to have a good sense of the coverage of the corpus from reading the data table, so it is necessary to create some visualizations of the records. For a quick prototyping tool, I am using the [`Bokeh`](http://bokeh.pydata.org/en/latest/) library.

# %%
from bokeh.charts import Bar, show
from bokeh.charts import defaults
from bokeh.palettes import viridis
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="59c86f15-a6fe-4366-8e60-661742891aa9">Loading BokehJS ...</span>
#     </div>

# %%
defaults.width = 900
defaults.height = 950

# %% [markdown]
# In this first graph, I am showing the total number of pages per title, per year in the corpus.

# %%
p = Bar(df, 
        'year', 
        values='docs',
        agg='sum', 
        stack='title',
        palette= viridis(30), 
        title="Pages per Title per Year")

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="010a7e43-118b-4baa-82c0-84583b1970b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("010a7e43-118b-4baa-82c0-84583b1970b0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("010a7e43-118b-4baa-82c0-84583b1970b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '010a7e43-118b-4baa-82c0-84583b1970b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"46fa9122-b51b-4885-a586-515b7c1e6109":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"CE","year":"1918"}],"color":["#472575"],"fill_alpha":[0.8],"height":[360.0],"label":[{"title":"CE","year":"1918"}],"line_alpha":[1.0],"line_color":["white"],"title":["CE"],"width":[0.8],"x":["1918"],"y":[180.0],"year":["1918"]}},"id":"5a84cf05-ab1a-46bf-a385-656c69194c16","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"82a846e3-3225-4010-9620-1fb11ecf50fd","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"YI","year":"1880"}],"color":["#FDE724"],"fill_alpha":[0.8],"height":[224.0],"label":[{"title":"YI","year":"1880"}],"line_alpha":[1.0],"line_color":["white"],"title":["YI"],"width":[0.8],"x":["1880"],"y":[1901.0],"year":["1880"]}},"id":"486b4608-cdf6-4aec-a115-29bd07675968","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"94f90a0a-62c0-4f86-ae6b-715f54be04f5","type":"ColumnDataSource"},"glyph":{"id":"76bf5d47-ab5f-490c-ac2b-3d523efba41a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8c59ee26-4f9d-4023-893d-259750500a11","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"SUW","year":"1908"}],"color":["#8BD546"],"fill_alpha":[0.8],"height":[250.0],"label":[{"title":"SUW","year":"1908"}],"line_alpha":[1.0],"line_color":["white"],"title":["SUW"],"width":[0.8],"x":["1908"],"y":[4482.0],"year":["1908"]}},"id":"457ddda4-4823-4802-95f9-33769df738c6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d5effe5-b668-4338-b416-f00d01079dbc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e3553069-7ad3-4470-a8f2-e8321ffd9640","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"YI","year":"1879"}],"color":["#FDE724"],"fill_alpha":[0.8],"height":[220.0],"label":[{"title":"YI","year":"1879"}],"line_alpha":[1.0],"line_color":["white"],"title":["YI"],"width":[0.8],"x":["1879"],"y":[1334.0],"year":["1879"]}},"id":"823e2a08-62fc-48f3-87df-6acd862056ba","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"GCB","year":"1903"}],"color":["#404487"],"fill_alpha":[0.8],"height":[228.0],"label":[{"title":"GCB","year":"1903"}],"line_alpha":[1.0],"line_color":["white"],"title":["GCB"],"width":[0.8],"x":["1903"],"y":[685.0],"year":["1903"]}},"id":"7426cace-c955-46c9-9dc6-fe9a002ea00f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be97e2fb-447b-429b-8251-bb621152de51","type":"Rect"},{"attributes":{"data_source":{"id":"dba8aacf-8005-4b4b-a4d1-55096f63e4e3","type":"ColumnDataSource"},"glyph":{"id":"2b6829bc-d ...

# %% [markdown]
# This graph of the corpus reflects the historical development of the publication efforts denomination. Starting with a single publication in 1849, the publishing efforts of the denomination expand in the 1860s as they launch their health reform efforts, expand again in the 1880s as they start a publishing house in California and address concerns about Sunday observance laws, and again at the turn of the century as the denomination reorganizes and regional publications expand. The chart also reveals some holes in the corpus. The *Youth's Instructor* (shown here in yellow) in one of the oldest continuous denominational publications, but the pages available for the years from 1850 - 1899 are inconsistent.
#
# In interpreting the results of mining these texts, it will be important to factor in the relative difference in size and diversity of publication venues between the early years of the denomination and the later years of this study.

# %%
by_title = df.groupby(["title"], as_index=False).docs.sum()

# %%
p = Bar(df, 
        'title', 
        values='docs', 
        color='title', 
        palette=viridis(30), 
        title="Total Pages by Title"
       )

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e68561af-8194-4068-9e2d-e5726c695317"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e68561af-8194-4068-9e2d-e5726c695317");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e68561af-8194-4068-9e2d-e5726c695317");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e68561af-8194-4068-9e2d-e5726c695317' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"41a705e4-c743-4221-83dc-23d48eab6c16":{"roots":{"references":[{"attributes":{"label":{"value":"IR"},"renderers":[{"id":"ab12e5da-4648-4f27-9d70-e8c792013c38","type":"GlyphRenderer"}]},"id":"fa959a12-f561-4ceb-9b35-13ec5b6b985b","type":"LegendItem"},{"attributes":{"data_source":{"id":"d9819cb6-6152-47cb-852e-8d9ac9d55fd2","type":"ColumnDataSource"},"glyph":{"id":"9cd49fd5-267c-4937-8165-2296da153559","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4e54c55f-d804-4e30-a881-d25a182cbcca","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"872193b7-1122-4918-860b-55f9f3e6759d","subtype":"Chart","type":"Plot"}},"id":"6efe0cf1-2e41-4a1d-b196-734176c31b25","type":"PanTool"},{"attributes":{"below":[{"id":"bf7a4dd1-231d-402a-bb02-584efa2550ea","type":"CategoricalAxis"}],"css_classes":null,"height":950,"left":[{"id":"454e35f7-a59a-40c5-a210-5cf0be698268","type":"LinearAxis"}],"renderers":[{"id":"99ae9285-fe59-4f14-9b75-3c5ec0071cd6","type":"BoxAnnotation"},{"id":"6de18724-7f98-45b0-8036-becb2e43ca5d","type":"GlyphRenderer"},{"id":"60165291-34ab-4221-ab62-3b5416ca87df","type":"GlyphRenderer"},{"id":"9d3322cd-e0ac-46e3-b6a4-1e6127f45dc3","type":"GlyphRenderer"},{"id":"02098034-738c-4721-92fc-6df29e664016","type":"GlyphRenderer"},{"id":"8f54036a-c9de-4ef1-a04b-f572bc55e54b","type":"GlyphRenderer"},{"id":"565933d4-9d30-48d5-8bbd-6bd9158ea170","type":"GlyphRenderer"},{"id":"af729b0e-5641-42c9-acf7-dc52ad6c0e76","type":"GlyphRenderer"},{"id":"11b55c4a-d4bd-4b68-929d-900385705f91","type":"GlyphRenderer"},{"id":"08b11b5b-eca5-4bd9-a9dd-ea5be325b183","type":"GlyphRenderer"},{"id":"863328a6-8152-4f69-9bda-1f8436701d11","type":"GlyphRenderer"},{"id":"9b263ada-a570-46e8-9846-ef822c0764b2","type":"GlyphRenderer"},{"id":"6103a9fd-a630-49e9-a6ff-4279252ca836","type":"GlyphRenderer"},{"id":"ab12e5da-4648-4f27-9d70-e8c792013c38","type":"GlyphRenderer"},{"id":"e920fca1-2f67-42c7-b319-deca1e2a0b31","type":"GlyphRenderer"},{"id":"eb4748f6-4fa4-4259-baca-78925e20d214","type":"GlyphRenderer"},{"id":"19fec901-112d-4740-81a7-884c4c770021","type":"GlyphRenderer"},{"id":"2bea468f-de7d-4ad5-afb0-490586ec5655","type":"GlyphRenderer"},{"id":"308a76ee-7787-4f81-90e6-3f343d9d3f52","type":"GlyphRenderer"},{"id":"8d655689-7ad1-4a08-8cc6-1c973c81e59e","type":"GlyphRenderer"},{"id":"fa50a1f4-da5f-43b1-a700-59b1a4bcd761","type":"GlyphRenderer"},{"id":"9fa8610c-d032-4dcf-9c09-194e12c0d8b9","type":"GlyphRenderer"},{"id":"5aadd087-6687-4157-b244-32b3697ddd12","type":"GlyphRenderer"},{"id":"feef1bfd-3f05-4dd5-9b42-81b61f8e8bdf","type":"GlyphRenderer"},{"id":"5a291b3b-d18f-425a-b3c4-94f69de7d762","type":"GlyphRenderer"},{"id":"a0c2600e-8cab-4212-aa57-1a7840c78c56","type":"GlyphRenderer"},{"id":"3c8a2664-5e00-423c-9099-c76e62166cc6","type":"GlyphRenderer"},{"id":"ff12e740-826c-4f3e-b07d-c8d9c498c195","type":"GlyphRenderer"},{"id":"bcd034ce-acb8-4dec-aca2-7fa07b1f38c4","type":"GlyphRenderer"},{"id":"7e773b16-70c5-458e-8641-924772d472fc","type":"GlyphRenderer"},{"id":"4e54c55f-d804-4e30-a881-d25a182cbcca","type":"GlyphRenderer"},{"id":"f0493924-6cf9-4489-8a74-47b71794057d","type":"Legend"},{"id":"bf7a4dd1-231d-402a-bb02-584efa2550ea","type":"CategoricalAxis"},{"id":"454e35f7-a59a-40c5-a210-5cf0be698268","type":"LinearAxis"},{"id":"33529586-f5c3-4cc0-8832-d369a48e8797","type":"Grid"}],"title":{"id":"8e81d1d1-892d-4f8b-bb7d-cc67352c2fe1","type":"Title"},"tool_events":{"id":"e16e471d-23e2-4069-b1e5-f0258622f21a","type":"ToolEvents"},"toolbar":{"id":"fa7e3ee1-7fa9-445b-8b36-0605ba1e3dcd","type":"Toolbar"},"width":900,"x_mapper_type":"auto","x_range":{"id":"867179ac-bd08-4196-a425-a6044f025cd1","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"0246659d-b164-48e0-85ae-51f6c2936e2a","type":"Range1d"}},"id":"872193b7-1122-4918-860b-55f9f3e6759d","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"a4c165ee-c31f-4cc9-aabf-a0f47db6338b","type":"ColumnDataSource"},"glyph":{"id":"d285b5d9-a14e-488c-84a0-d19985949673","type ...

# %% [markdown]
# Another way to view the coverage of the corpus is by total pages per periodical title. The *Advent Review and Sabbath Herald* dominates the corpus in number of pages, with *The Health Reformer*, *Signs of the Times*, and the *Youth's Instructor*, making up the next major percentage of the corpus. In terms of scale, these publications will have (and had) a prominent role in shaping the discourse of the SDA community. At the same time, it will be informative to look to the smaller publications to see if we can surface alternative and dissonant ideas.

# %%
topic_metadata = pd.read_csv('data/2017-05-05-periodical-topics.csv')

# %%
topic_metadata
# Out:
#                                    periodicalTitle  title  startYear  endYear  \
# 0                         Training School Advocate    ADV       1898     1905
# 1                                American Sentinel   AmSn       1886     1900
# 2                 Advent Review and Sabbath Herald   ARAI       1909     1919
# 3                              Christian Education     CE       1909     1920
# 4         Welcome Visitor (Columbia Union Visitor)    CUV       1901     1920
# 5                               Christian Educator    EDU       1897     1899
# 6                      General Conference Bulletin    GCB       1863     1918
# 7                                    Gospel Herald     GH       1898     1920
# 8                                 Gospel of Health    GOH       1897     1899
# 9                                    Gospel Sickle     GS       1886     1888
# 10                                 Home Missionary     HM       1889     1897
# 11                                 Health Reformer     HR       1866     1907
# 12                                Indiana Reporter     IR       1901     1910
# 13                                       Life Boat     LB       1898     1920
# 14                                 Life and Health     LH       1904     1920
# 15                                         Liberty   LibM       1906     1920
# 16                               Lake Union Herald    LUH       1908     1920
# 17                       North Michigan News Sheet    NMN       1907     1910
# 18  Pacific Health Journal and Temperance Advocate    PHJ       1885     1904
# 19                   Present Truth (Advent Review)   PTAR       1849     1850
# 20                          Pacific Union Recorder    PUR       1901     1920
# 21                               Review and Herald     RH       1850     1920
# 22                                       Sligonian  Sligo       1916     1920
# 23                             Sentinel of Liberty    SOL       1900     1904
# 24                              Signs of the Times     ST       1874     1920
# 25   Report of Progress, Southern Union Conference    SUW       1907     1920
# 26                        Church Officer's Gazette   TCOG       1914     1920
# 27                         The Missionary Magazine    TMM       1898     1902
# 28                            West Michigan Herald    WMH       1903     1908
# 29                              Youth's Instructor     YI       1852     1920
#
#      initialPubLocation              topic
# 0      Battle Creek, MI          Education
# 1           Oakland, CA  Religious Liberty
# 2      Washington, D.C.     Denominational
# 3      Washington, D.C.          Education
# 4          Academia, OH           Regional
# 5      Battle Creek, MI          Education
# 6      Battle Creek, MI     Denominational
# 7        Yazoo City, MS           Regional
# 8      Battle Creek, MI             Health
# 9      Battle Creek, MI           Missions
# 10     Battle Creek, MI           Missions
# 11     Battle Creek, MI             Health
# 12     Indianapolis, IN           Regional
# 13          Chicago, IL           Missions
# 14     Washington, D.C.             Health
# 15     Washington, D.C.  Religious Liberty
# 16  Berrien Springs, MI           Regional
# 17         Petoskey, MI           Regional
# 18          Oakland, CA             Health
# 19       Middletown, CT     Denominational
# 20          Oakland, CA           Regional
# 21            Paris, ME     Denominational
# 22     Washington, D.C.           Regional
# 23          Chicago, IL  Religious Liberty
# 24          Oakland, CA     Denominational
# 25        Nashville, TN           Regional
# 26     Washington, D.C.     Denominational
# 27     Philadelphia, PA           Missions
# 28     Grand Rapids, MI           Regional
# 29        Rochester, NY     Denominational

# %% [markdown]
# We can generate another view by adding some external metadata for the titles. The "topics" listed here are ones I assigned when skimming the different titles. "Denominational" refers to centrally produced publications, covering a wide array of topics. "Education" refers to periodicals focused on education. "Health" to publications focused on health. "Missions" titles are focused on outreach and evangelism focused publications and "Religious Liberty" on governmental concerns over Sabbath laws. Finally, "Regional" refers to periodicals produced by local union conferences, which like the denominational titles cover a wide range of topics.

# %%
by_topic = pd.merge(topic_metadata, df, on='title')

# %%
p = Bar(by_topic, 
        'year', 
        values='docs',
        agg='sum', 
        stack='topic',
        palette= viridis(6), 
        title="Pages per Topic per Year")

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dd9596d3-5d68-45b8-b33b-fbf6737bceaf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dd9596d3-5d68-45b8-b33b-fbf6737bceaf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dd9596d3-5d68-45b8-b33b-fbf6737bceaf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dd9596d3-5d68-45b8-b33b-fbf6737bceaf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e83f76be-3545-4eaa-b987-097e93610994":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"topic":"Missions","year":"1901"}],"color":["#22A784"],"fill_alpha":[0.8],"height":[268.0],"label":[{"topic":"Missions","year":"1901"}],"line_alpha":[1.0],"line_color":["white"],"topic":["Missions"],"width":[0.8],"x":["1901"],"y":[2744.0],"year":["1901"]}},"id":"d7032fa1-9c63-429d-90f5-f7dc488d8331","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"topic":"Religious Liberty","year":"1916"}],"color":["#FDE724"],"fill_alpha":[0.8],"height":[240.0],"label":[{"topic":"Religious Liberty","year":"1916"}],"line_alpha":[1.0],"line_color":["white"],"topic":["Religious Liberty"],"width":[0.8],"x":["1916"],"y":[3582.0],"year":["1916"]}},"id":"52a5f34e-6e8d-4301-b4c6-d9683523242b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"topic":"Denominational","year":"1889"}],"color":["#440154"],"fill_alpha":[0.8],"height":[1996.0],"label":[{"topic":"Denominational","year":"1889"}],"line_alpha":[1.0],"line_color":["white"],"topic":["Denominational"],"width":[0.8],"x":["1889"],"y":[1384.0],"year":["1889"]}},"id":"27923b8f-7059-4a29-b5ef-c2cfb7f176de","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fb89d997-c1a7-4b16-9f01-632a5496cace","type":"ColumnDataSource"},"glyph":{"id":"ef58f693-e55d-4502-b513-2fe08d8a0a6d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"12a77bce-90e2-4795-ac57-f6df8a06fdfe","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"308d4a72-ea42-46c4-86a6-bab15803f0f6","type":"Rect"},{"attributes":{"data_source":{"id":"38ba5114-b15d-436e-a698-975946d059fb","type":"ColumnDataSource"},"glyph":{"id":"9f0e8d3e-dfcc-400d-8cef-62729d7519dc","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c026577a-7573-476d-9c01-8f2527b7293e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b6565e9-60ad-4b0d-bfc4-a7ad3dfc2252","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"topic":"Regional","year":"1916"}],"color":["#79D151"],"fill_alpha":[0.8],"height":[2046.0],"label":[{"topic":"Regional","year":"1916"}],"line_alpha":[1.0],"line_color":["white"],"topic":["Regional"],"width":[0.8],"x":["1916"],"y":[1383.0],"year":["1916"]}},"id":"fd870043-2647-4649-993c-0fccc49c977a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ec4b36a8-245f-4795-a83c-a3c5d59ba342","type":"ColumnDataSource"},"glyph":{"id":"b8a544a8-10e9-4172-8ea5-356e0191cae0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"59485740-8eb8-4786-a4ad-78ccf8d9e33a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"28593119-948f-4b0d-b9a7-8de5f7719f78","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"topic":"Health","year":"1919"}],"color":["#29788E"],"fill_alpha":[ ...

# %% [markdown]
# Here we can see the diversification of periodical subjects over time, especially around the turn of the century.

# %%
p = Bar(by_topic, 
        'topic', 
        values='docs',
        agg='sum', 
        stack='title',
        palette= viridis(30), 
        title="Pages per Topic per Year")

# %%
p.left[0].formatter.use_scientific = False
p.legend.location = "top_right"

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ba5afbb-d7bc-4730-9920-877e4f1d3050"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ba5afbb-d7bc-4730-9920-877e4f1d3050");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ba5afbb-d7bc-4730-9920-877e4f1d3050");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ba5afbb-d7bc-4730-9920-877e4f1d3050' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5d523609-2f12-4ae1-874b-f875caa6b68e":{"roots":{"references":[{"attributes":{"data_source":{"id":"dc53ecbb-9710-412a-b514-34d68e32a299","type":"ColumnDataSource"},"glyph":{"id":"56099606-d0d8-4c59-9aac-d52495c66e75","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d3c13632-639c-4a91-aec6-9e5a69baf6b3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2753a7c2-2e0c-4f12-957e-3c6fa75df3a3","type":"ColumnDataSource"},"glyph":{"id":"42c1a80d-b8fa-4f91-b1cc-140f4269a543","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"99a3eb4e-4e00-43df-8ddd-1ff1ce92dc5f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","fill_alpha","label","width","height","color","line_alpha","x","y"],"data":{"chart_index":[{"title":"WMH","topic":"Regional"}],"color":["#E7E419"],"fill_alpha":[0.8],"height":[1043.0],"label":[{"title":"WMH","topic":"Regional"}],"line_alpha":[1.0],"line_color":["white"],"title":["WMH"],"topic":["Regional"],"width":[0.8],"x":["Regional"],"y":[29029.5]}},"id":"3794e4b9-ab0f-49ef-9622-2f247795e274","type":"ColumnDataSource"},{"attributes":{"label":{"value":"LB"},"renderers":[{"id":"dea3a032-f630-4753-9ec4-c3d7a7f499ed","type":"GlyphRenderer"}]},"id":"73bb8e84-6de7-475c-9c88-d725e74ef11d","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6b3bb5ac-1745-4ae5-9b66-5cdd8a482439","type":"Rect"},{"attributes":{"data_source":{"id":"abaf651d-9e9a-4332-8b75-bfea127bc3e3","type":"ColumnDataSource"},"glyph":{"id":"7645bc55-f462-4bb7-9724-af42c3e60891","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b140b88a-ea20-4d37-9c90-3b174ba4c415","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"d30f7491-befc-4411-924e-9b4134926dd0","subtype":"Chart","type":"Plot"},"ticker":{"id":"05e96f44-886a-4ee3-8f21-fe03758cf515","type":"BasicTicker"}},"id":"768e9579-2031-462b-a7da-9a8bf88d0598","type":"Grid"},{"attributes":{"label":{"value":"IR"},"renderers":[{"id":"0863223f-8fbf-4ac3-a770-759d991ac166","type":"GlyphRenderer"}]},"id":"e2a4f957-1d96-4c6b-9fcc-4050c6566532","type":"LegendItem"},{"attributes":{"label":{"value":"GS"},"renderers":[{"id":"522fcbeb-35a4-4a30-815b-f089c6028ac1","type":"GlyphRenderer"}]},"id":"8dbdb6c6-7457-4a0c-97a0-da33925239cc","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4aa8b28b-bf21-44a1-8e30-9c8de69873d9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb320406-a97f-46b6-b0cd-c563afd39048","type":"Rect"},{"attributes":{"plot":null,"text":"Pages per Topic per Year"},"id":"16ff8039-6053-4fd8-b2c0-d1d5d8233b30","type":"Title"},{"attributes":{"callback":null,"factors":["Denominational","Education","Health","Missions","Regional","Religious Liberty"]},"id":"f693e845-8143-4f7c-b64e-524b07c8550f","type":"FactorRange"},{"attributes":{"axis_label":"Topic","formatter":{"id":"fff2d08f-958e-4e30-9a49-2c1da9adc7ce","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"d30f7491-befc-4411-924e-9b4134926dd0","subtype":"Chart","type":"Plot"},"ticker":{"id":"e87ec1f5-4bb4-406a-94a5-4d909ffdda4b","type":"CategoricalTicker"}},"id":"d5297009-272e-41c3-8946-f5588e34fb7a","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"8b63732f-3973-4ef4-91a8-43eef10961a0","type":"ColumnDataSource"},"glyph":{"id":"6180ee23-e434-41bb-bcec-09a640a531bb","type":"Rect ...

# %% [markdown]
# Grouping by category allows us to see that our corpus is dominated by the denominational, health, and regionally focused publications. These topics match with our research concerns, increasing our confidence that we will have enough information to determine meaningful patterns about those topics. But, due to the focus of the corpus, we should proceed cautiously before making any claims about the relative importance of those topics within the community.
#
# Now that we have a sense of the temporal and topical coverage of our corpus, we will next turn our attention to evaluating the quality of the data that we have gathered from the scanned PDF files.
